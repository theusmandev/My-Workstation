# %%
class Person:
    def __init__(self, name):
        self.name = name

    def greet(self):  # function declared inside the object (class)
        return "Hello, " + self.name

# Create an object (instance)
p = Person("Usman")

# Call the function (method)
print(p.greet())  # Output: Hello, Usman
# Out:
# Hello, Usman
