# %%
from collections import defaultdict

# Create a defaultdict with list as default type
my_dict = defaultdict(list)

# Access non-existing key "apple"
print(my_dict["apple"])  # ✅ Output: []

# Append something to it
my_dict["apple"].append("red")
my_dict["mango"].append("yellow")

print(my_dict)
# Out:
# []
# defaultdict(<class 'list'>, {'apple': ['red'], 'banana': ['yellow']})
