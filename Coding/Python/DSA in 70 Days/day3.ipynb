# %% [markdown]
# Kadane’s Algorithm (Fixed Window)

# %%
nums = [-2, 1, -3, 4, -1, 2, 1, -5]
def maxSubArray(nums):
    max_sum = current_sum = nums[0]

    for num in nums[1:]:
        current_sum = max(num, current_sum + num)
        max_sum = max(max_sum, current_sum)

    return max_sum
print(maxSubArray(nums))
# Out:
# 6

# %%
nums = [-2,1,-3,4,-1,2,1,-5,4]
def maxSubArray(nums):
    max_sum  =current_sum = nums[0]
    start = end = temp_start = 0
    for i in range(1,len(nums)):
        if nums[i]>current_sum+nums[i]:
            current_sum = nums[i]
            temp_start = i
        else:
            current_sum += nums[i]
        if current_sum>max_sum:
            max_sum = current_sum
            start = temp_start
            end = i
    print("Max sum:",max_sum)
    print("max sub array:",nums[start:end+1])
    return max_sum
maxSubArray(nums)
# Out:
# Max sum: 6
# max sub array: [4, -1, 2, 1]
# 6

# %%
nums = [-2, 1, -3, 4, -1, 2, 1, -5, 4,3]

def maxSubArray(nums):
    max_sum = current_sum = nums[0]
    start = end = temp_start = 0

    for i, num in enumerate(nums[1:], start=1):
        if num > current_sum + num:
            current_sum = num
            temp_start = i
        else:
            current_sum += num

        if current_sum > max_sum:
            max_sum = current_sum
            start = temp_start
            end = i

    print("Max sum:", max_sum)
    print("Max subarray:", nums[start:end+1])

    return max_sum

maxSubArray(nums)
# Out:
# Max sum: 6
# Max subarray: [4, -1, 2, 1]
# 6

# %% [markdown]
# Brute Force Approach

# %%
def maxSubArray(nums):
    max_sum = float('-inf')
    for i in range(len(nums)):
        current_sum = 0 
        for j in range(i,len(nums)):
            current_sum += nums[j]
            max_sum = max(max_sum,current_sum)
    return max_sum

# %% [markdown]
# LeetCode Format (Python):

# %%
from typing import List

class Solution:
    def maxSubArray(self, nums: List[int]) -> int:
        max_sum = current_sum = nums[0]

        for num in nums[1:]:
            current_sum = max(num, current_sum + num)
            max_sum = max(max_sum, current_sum)

        return max_sum
