# %%
def test(n):
    print(n)
    if n == 2000:
        return "Base case"
    return test(n + 1)

test(1)

# %%
def call(n):
    print (n)
    return call(n+1)

call(1)

# %%
n = 5

def factorial(n):
    if n == 0:
        return 1
    return n * factorial(n - 1)

print(factorial(n))  # Output: 120

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n - 1)
print(factorial(n))

# %%
def get_grade(marks):
    if marks >= 90:
        return 'A'
    elif marks >= 80:
        return 'B'
    elif marks >= 70:
        return 'C'
    elif marks >= 60:
        return 'D'
    else:
        return 'F'

marks = int(input("Enter your marks: "))  # Convert to integer
print("Your grade is:", get_grade(marks))

# %%
def get_grade(marks):
    if marks >= 90:
        return 'A'
    elif marks >= 80:
        return 'B'
    elif marks >= 70:
        return 'C'
    elif marks >= 60:
        return 'D'
    else:
        return 'F'

# Get input safely
user_input = input("Enter your marks: ")

# Check if input is not empty and is a number
if user_input.strip().isdigit():
    marks = int(user_input)
    print("Your grade is:", get_grade(marks))
else:
    print("❌ Please enter a valid number.")
# Out:
# Your grade is: F

# %%
def get_grade(marks):
    if marks >= 90:
        return 'A'
    elif marks >= 80:
        return 'B'
    elif marks >= 70:
        return 'C'
    elif marks >= 60:
        return 'D'
    else:
        return 'F'

marks = 85  # direct number input
print("Your grade is:", get_grade(marks))

# %%
from ipywidgets import interact

def get_grade(marks):
    if marks >= 90:
        return 'A'
    elif marks >= 80:
        return 'B'
    elif marks >= 70:
        return 'C'
    elif marks >= 60:
        return 'D'
    else:
        return 'F'

@interact(marks=(0, 100))
def show_grade(marks=0):
    print("Your grade is:", get_grade(marks))
# Out:
# interactive(children=(IntSlider(value=0, description='marks'), Output()), _dom_classes=('widget-interact',))

# %%
pip install ipywidgets
